# %% [markdown]
# # Wykład 6 (cz. 1) - Markdown w Jupterze, kilka przykładów

# %% [markdown]
# To jest komórka typu Markdown https://en.wikipedia.org/wiki/Markdown
#
# Kliknij dwukrotnie na komórkę, żeby zobaczyć jej źródło (a następnie <kbd>Shift</kbd> + <kbd>Enter</kbd>, aby ją "wykonać").
#
# Dalsze komórki: przykłady na elementy Markdowna.

# %% [markdown]
# Formatowanie tekstu: *abc*, **abc**, ~abc~.

# %% [markdown]
# # Duży nagłówek
#
# ## Mniejszy nagłówek
#
# ### Jeszcze mniejszy nagłówek

# %% [markdown]
# Lista:
# * opcja 1
# * opcja 2

# %% [markdown]
# Lista zagnieżdżona i checkboxy:
# - opcja 1
# - opcja 2
#   - [x] zadanie 1
#   - [ ] zadanie 2

# %% [markdown]
# Obrazek:
# ![alternatywny tekst](blincat.jpg)

# %% [markdown]
# Font monospace, typowy dla kodu: `tekst` ("... przykładem pętli w Pythonie jest pętla `for`...")

# %% [markdown]
# Dłuższy blok kodu, z podświetloną składnią:
# ```python
# for i in range(10):
#     print(i)
# ```
#
# Nie tylko Python:
# ```C++
# using namespace std;
# ```

# %% [markdown]
# Można też używać (podzbioru) HTMLa:
#
# <mark>Tekst</mark><br/><code>tekst</code><br/>tekst
#
# <b><i>abc</i> abc <s>abc</s></b>

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=dQw4w9WgXcQ">Własny link!</a>

# %% [markdown]
# Bonus: tabelka
# <table>
#     <tr><td>A</td><td>B</td></tr>
#     <tr><td>C</td><td>D</td></tr>
# </table>

# %% [markdown]
# Obraz, ale z użyciem HTML:
# <img src="blincat.jpg" width=150 />

# %% [markdown]
# HTML z użyciem "Jupyterowej magii":

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/lOXIpsoEo2w?si=dLYNfaO5DY4Iiw9O" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/lOXIpsoEo2w?si=dLYNfaO5DY4Iiw9O" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# Nie tylko Markdown: wideo z użyciem obiektów IPythona (interaktywnego interpretera na którym zbudowany jest Jupyter)

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("lOXIpsoEo2w")

# %% [markdown]
# Inne interesujące obiekty (typy) w `IPython.display`: `Audio`, `Code`, `Image`, szereg innych - https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html#module-IPython.display

# %% [markdown]
# Nie tylko HTML, ale też formuły matematyczne w (podzbiorze) Latexa:
#
# $$\sum_{i=1}^\infty \frac{1}{n} = \infty.$$
#
# $$A \cap (B \cup C) = (A \cap B) \cup (A \cap C).$$
